# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint as pprint

from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

import requests
import pymongo

# %%
#Get all tv shows by API calls to TV Maze Website 
base_url = "http://api.tvmaze.com/shows"
response = requests.get(base_url).json()
df = pd.DataFrame(response)

# %%
#Get Required columns
df = df[['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime','premiered', 'officialSite', 'schedule', 'network']]
df.head()
# Out:
#    id                                                url                name  \
# 0   1      https://www.tvmaze.com/shows/1/under-the-dome      Under the Dome
# 1   2  https://www.tvmaze.com/shows/2/person-of-interest  Person of Interest
# 2   3              https://www.tvmaze.com/shows/3/bitten              Bitten
# 3   4               https://www.tvmaze.com/shows/4/arrow               Arrow
# 4   5      https://www.tvmaze.com/shows/5/true-detective      True Detective
#
#        type language                              genres   status  runtime  \
# 0  Scripted  English  [Drama, Science-Fiction, Thriller]    Ended     60.0
# 1  Scripted  English    [Action, Crime, Science-Fiction]    Ended     60.0
# 2  Scripted  English            [Drama, Horror, Romance]    Ended     60.0
# 3  Scripted  English    [Drama, Action, Science-Fiction]    Ended     60.0
# 4  Scripted  English            [Drama, Crime, Thriller]  Running     60.0
#
#     premiered                                  officialSite  \
# 0  2013-06-24      http://www.cbs.com/shows/under-the-dome/
# 1  2011-09-22  http://www.cbs.com/shows/person_of_interest/
# 2  2014-01-11                       http://bitten.space.ca/
# 3  2012-10-10               http://www.cwtv.com/shows/arrow
# 4  2014-01-12             http://www.hbo.com/true-detective
#
#                                   schedule  \
# 0  {'time': '22:00', 'days': ['Thursday']}
# 1   {'time': '22:00', 'days': ['Tuesday']}
# 2    {'time': '22:00', 'days': ['Friday']}
# 3   {'time': '21:00', 'days': ['Tuesday']}
# 4    {'time': '21:00', 'days': ['Sunday']}
#
#                                              network
# 0  {'id': 2, 'name': 'CBS', 'country': {'name': '...
# 1  {'id': 2, 'name': 'CBS', 'country': {'name': '...
# 2  {'id': 7, 'name': 'CTV Sci-Fi Channel', 'count...
# 3  {'id': 5, 'name': 'The CW', 'country': {'name'...
# 4  {'id': 8, 'name': 'HBO', 'country': {'name': '...

# %%
#Cleaning the Data, replace the empty values with NA

#Replace the empty data values to 'NA' which are not avaiable 
df.replace(np.NAN,'NA', inplace=True)

#Replace the data values which are not relevant to 'NA' 
df.replace('[]','NA', inplace=True)

# %%
#Clean the dataframe to remove the duplicates TV shows 
duplicate = df[df.duplicated('name')]
if(duplicate.empty):
    print("No duplicate TV shows in the Dataframe")
else:
    print(duplicate)
    print('---------------------------------')
# Out:
#       id                                      url    name     type language  \
# 145  153  https://www.tvmaze.com/shows/153/utopia  Utopia  Reality  English
#
#     genres status runtime   premiered officialSite  \
# 145     []  Ended      60  2014-09-07           NA
#
#                                   schedule  \
# 145  {'time': '20:00', 'days': ['Friday']}
#
#                                                network
# 145  {'id': 4, 'name': 'FOX', 'country': {'name': '...
# ---------------------------------

# %%
print(f"Current Record Count:   {len(df)}")
print('Dropping the duplicates....')
df.drop_duplicates(subset=['name'], keep='first', inplace=True)
print(f"New Record Count:   {len(df)}")
# Out:
# Current Record Count:   240
# Dropping the duplicates....
# New Record Count:   239

# %%
#Changing the Index of a DataFrame
df = df.set_index('name')

# %%
#Read the schedule which was in a dictionary, transformed the data in to new columns- Time and Day
time_lst = []
day_lst=[]

schedule = df['schedule']

for sch in schedule:
    time_lst.append(sch['time'])
    day_lst.append(sch['days'])
    
#Add these two new columns to the existing DataFrame.
df['Time'] = time_lst
df['Day'] = day_lst

# %%
#Network column has data stored as a dictonary of dictionaries.
#Read the data fetched the dictionary items, seperated in new lists and  appended the 
nw_name_lst = []
country_name_lst=[]
country_code=[]
timezone_lst=[]

network = df['network']

for nw in network:
    if(nw!='NA'):
        nw_name_lst.append(nw['name'])
        country_name_lst.append(nw['country']['name'])
        country_code.append(nw['country']['code'])
        timezone_lst.append(nw['country']['timezone'])
    else:
         nw_name_lst.append('')
         country_name_lst.append('')
         country_code.append('')
         timezone_lst.append('')
    
df['Network'] = nw_name_lst
df['Country'] = country_name_lst   
df['Country Code'] = country_code
df['Timezone'] = timezone_lst
df.head()
# Out:
#                     id                                                url  \
# name
# Under the Dome       1      https://www.tvmaze.com/shows/1/under-the-dome
# Person of Interest   2  https://www.tvmaze.com/shows/2/person-of-interest
# Bitten               3              https://www.tvmaze.com/shows/3/bitten
# Arrow                4               https://www.tvmaze.com/shows/4/arrow
# True Detective       5      https://www.tvmaze.com/shows/5/true-detective
#
#                         type language                              genres  \
# name
# Under the Dome      Scripted  English  [Drama, Science-Fiction, Thriller]
# Person of Interest  Scripted  English    [Action, Crime, Science-Fiction]
# Bitten              Scripted  English            [Drama, Horror, Romance]
# Arrow               Scripted  English    [Drama, Action, Science-Fiction]
# True Detective      Scripted  English            [Drama, Crime, Thriller]
#
#                      status runtime   premiered  \
# name
# Under the Dome        Ended      60  2013-06-24
# Person of Interest    Ended      60  2011-09-22
# Bitten                Ended      60  2014-01-11
# Arrow                 Ended      60  2012-10-10
# True Detective      Running      60  2014-01-12
#
#                                                     officialSite  \
# name
# Under the Dome          http://www.cbs.com/shows/under-the-dome/
# Person of Interest  http://www.cbs.com/shows/person_of_interest/
# Bitten                                   http://bitten.space.ca/
# Arrow                            http://www.cwtv.com/shows/arrow
# True Detective                 http://www.hbo.com/true-detective
#
#                                                    schedule  \
# name
# Under the Dome      {'time': '22:00', 'days': ['Thursday']}
# Person of Interest   {'time': '22:00', 'days': ['Tuesday']}
# Bitten                {'time': '22:00', 'days': ['Friday']}
# Arrow                {'time': '21:00', 'days': ['Tuesday']}
# True Detective        {'time': '21:00', 'days': ['Sunday']}
#
#                                                               network   Time  \
# name
# Under the Dome      {'id': 2, 'name': 'CBS', 'country': {'name': '...  22:00
# Person of Interest  {'id': 2, 'name': 'CBS', 'country': {'name': '...  22:00
# Bitten              {'id': 7, 'name': 'CTV Sci-Fi Channel', 'count...  22:00
# Arrow               {'id': 5, 'name': 'The CW', 'country': {'name'...  21:00
# True Detective      {'id': 8, 'name': 'HBO', 'country': {'name': '...  21:00
#
#                            Day             Network        Country  \
# name
# Under the Dome      [Thursday]                 CBS  United States
# Person of Interest   [Tuesday]                 CBS  United States
# Bitten                [Friday]  CTV Sci-Fi Channel         Canada
# Arrow                [Tuesday]              The CW  United States
# True Detective        [Sunday]                 HBO  United States
#
#                    Country Code          Timezone
# name
# Under the Dome               US  America/New_York
# Person of Interest           US  America/New_York
# Bitten                       CA   America/Halifax
# Arrow                        US  America/New_York
# True Detective               US  America/New_York

# %%
#Drop the columns that are not further required 
del df['id']
del df['schedule']
del df['network']

# %%
#Rename the columns 
df.rename(columns = {'url':'Show URL','name':'Name','type':'Show Type','language':'Language','genres':'Genres','status':'Status','runtime':'Runtime','premiered':'Premiere Date','officialSite':'Official Site'}, inplace = True)

# %%
df.head()
# Out:
#                                                              Show URL  \
# name
# Under the Dome          https://www.tvmaze.com/shows/1/under-the-dome
# Person of Interest  https://www.tvmaze.com/shows/2/person-of-interest
# Bitten                          https://www.tvmaze.com/shows/3/bitten
# Arrow                            https://www.tvmaze.com/shows/4/arrow
# True Detective          https://www.tvmaze.com/shows/5/true-detective
#
#                    Show Type Language                              Genres  \
# name
# Under the Dome      Scripted  English  [Drama, Science-Fiction, Thriller]
# Person of Interest  Scripted  English    [Action, Crime, Science-Fiction]
# Bitten              Scripted  English            [Drama, Horror, Romance]
# Arrow               Scripted  English    [Drama, Action, Science-Fiction]
# True Detective      Scripted  English            [Drama, Crime, Thriller]
#
#                      Status Runtime Premiere Date  \
# name
# Under the Dome        Ended      60    2013-06-24
# Person of Interest    Ended      60    2011-09-22
# Bitten                Ended      60    2014-01-11
# Arrow                 Ended      60    2012-10-10
# True Detective      Running      60    2014-01-12
#
#                                                    Official Site   Time  \
# name
# Under the Dome          http://www.cbs.com/shows/under-the-dome/  22:00
# Person of Interest  http://www.cbs.com/shows/person_of_interest/  22:00
# Bitten                                   http://bitten.space.ca/  22:00
# Arrow                            http://www.cwtv.com/shows/arrow  21:00
# True Detective                 http://www.hbo.com/true-detective  21:00
#
#                            Day             Network        Country  \
# name
# Under the Dome      [Thursday]                 CBS  United States
# Person of Interest   [Tuesday]                 CBS  United States
# Bitten                [Friday]  CTV Sci-Fi Channel         Canada
# Arrow                [Tuesday]              The CW  United States
# True Detective        [Sunday]                 HBO  United States
#
#                    Country Code          Timezone
# name
# Under the Dome               US  America/New_York
# Person of Interest           US  America/New_York
# Bitten                       CA   America/Halifax
# Arrow                        US  America/New_York
# True Detective               US  America/New_York

# %%
#Generate an output as CSV from the API call
df.to_csv('Output/tvmaze_api_output.csv', encoding='utf-8')

# %%
# Get further data on TV shows by using Web Scrapping

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\amita\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
#Visit every TV show website, web scrape the data, get the details of Show like -
#Created By, Full Image, Med Image, Rating, Rating Count

#Create empty list for the new datafrom web scrapping
show_sum = []
full_img=[]
med_img=[]
crtd_by = []
rtng = []
rtng_cnt=[]
url_list = df['Show URL']

#Pass each TV URl,call the URL, fetch the data
#There are around 239 TV shows, some may have the show-info details some may not, 
#so added checks and validations to fetch data for allshows.

for url in url_list:
    print(url)
    browser.visit(url)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    gen_info = soup.find(id='general-information')
    show_sum.append(gen_info.p.text)
    med_img.append(gen_info.img['src'])
   
    full_img.append(soup.find("meta",  property="og:image")['content'])
    
    soup_info=soup.find(id="general-info-panel")
    all_div = soup_info.find_all('div')

    isPresent = False
    for tag in all_div:
        if "Created by:" not in tag.text: 
            continue
        else:
            crtd_by.append(tag.find('span').text)
            isPresent = True
            break
            
    if(isPresent==False):
        crtd_by.append('')
        
    rating = soup_info.find_all("span", itemprop="aggregateRating")

    for tag in rating:
        if(tag.find("b")):
            rtng.append(tag.b.text)
        else:
            rtng.append('')   
    
    for tag in rating:
        if(tag.find("span", itemprop="ratingCount")): 
            rtng_cnt.append(tag.find("span", itemprop="ratingCount").text)
        else:
            rtng_cnt.append('')
# Out:
# https://www.tvmaze.com/shows/1/under-the-dome
# https://www.tvmaze.com/shows/2/person-of-interest
# https://www.tvmaze.com/shows/3/bitten
# https://www.tvmaze.com/shows/4/arrow
# https://www.tvmaze.com/shows/5/true-detective
# https://www.tvmaze.com/shows/6/the-100
# https://www.tvmaze.com/shows/7/homeland
# https://www.tvmaze.com/shows/8/glee
# https://www.tvmaze.com/shows/9/revenge
# https://www.tvmaze.com/shows/10/grimm
# https://www.tvmaze.com/shows/11/gotham
# https://www.tvmaze.com/shows/12/lost-girl
# https://www.tvmaze.com/shows/13/the-flash
# https://www.tvmaze.com/shows/14/continuum
# https://www.tvmaze.com/shows/15/constantine
# https://www.tvmaze.com/shows/16/penny-dreadful
# https://www.tvmaze.com/shows/18/the-amazing-race
# https://www.tvmaze.com/shows/19/supernatural
# https://www.tvmaze.com/shows/20/the-strain
# https://www.tvmaze.com/shows/21/the-last-ship
# https://www.tvmaze.com/shows/22/true-blood
# https://www.tvmaze.com/shows/23/once-upon-a-time-in-wonderland
# https://www.tvmaze.com/shows/24/hawaii-five-0
# https://www.tvmaze.com/shows/25/hellsing
# https://www.tvmaze.com/shows/26/hellsing-ultimate
# https://www.tvmaze.com/shows/27/berserk
# https://www.tvmaze.com/shows/28/californication
# https://www.tvmaze.com/shows/29/vikings
# https://www.tvmaze.com/shows/30/american-horror-story
# https://www.tvmaze.com/shows/31/marvels-agents-of-shield
# https://www.tvmaze.com/shows/32/fargo
# https://www.tvmaze.com/shows/33/hemlock-grove
# https://www.tvmaze.com/shows/34/helix
# https://www.tvmaze.com/shows/35/the-killing
# https://www.tvmaze.com/shows/37/intruders
# https://www.tvmaze.com/shows/38/z-nation
# https://www.tvmaze.com/shows/39/resurrection
# https://www.tvmaze.com/shows/40/death-note
# https://www.tvmaze.com/shows/41/last-man-standing
# https://www.tvmaze.com/shows/42/sleepy-hollow
# https://www.tvmaze.com/shows/43/outlander
# https://www.tvmaze.com/shows/44/scorpion
# https://www.tvmaze.com/shows/45/ncis-new-orleans
# https://www.tvmaze.com/shows/46/forever
# https://www.tvmaze.com/shows/47/witches-of-east-end
# https://www.tvmaze.com/shows/48/madam-secretary
# https://www.tvmaze.com/shows/49/brooklyn-nine-nine
# https://www.tvmaze.com/shows/50/the-lottery
# https://www.tvmaze.com/shows/51/the-knick
# https://www.tvmaze.com/shows/52/how-to-get-away-with-murder
# https://www.tvmaze.com/shows/53/nashville
# https://www.tvmaze.com/shows/54/legends
# https://www.tvmaze.com/shows/55/red-band-society
# https://www.tvmaze.com/shows/56/chicago-pd
# https://www.tvmaze.com/shows/57/black-ish
# https://www.tvmaze.com/shows/58/new-girl
# https://www.tvmaze.com/shows/59/chicago-fire
# https://www.tvmaze.com/shows/60/ncis
# https://www.tvmaze.com/shows/61/orphan-black
# https://www.tvmaze.com/shows/62/the-originals
# https://www.tvmaze.com/shows/63/the-vampire-diaries
# https://www.tvmaze.com/shows/64/utopia
# https://www.tvmaze.com/shows/65/bones
# https://www.tvmaze.com/shows/66/the-big-bang-theory
# https://www.tvmaze.com/shows/67/greys-anatomy
# https://www.tvmaze.com/shows/68/castle
# https://www.tvmaze.com/shows/69/the-blacklist
# https://www.tvmaze.com/shows/70/the-voice
# https://www.tvmaze.com/shows/71/dancing-with-the-stars
# https://www.tvmaze.com/shows/72/ncis-los-angeles
# https://www.tvmaze.com/shows/73/the-walking-dead
# https://www.tvmaze.com/shows/74/hell-on-wheels
# https://www.tvmaze.com/shows/75/the-mindy-project
# https://www.tvmaze.com/shows/76/sons-of-anarchy
# https://www.tvmaze.com/shows/77/the-middle
# https://www.tvmaze.com/shows/78/the-mysteries-of-laura
# https://www.tvmaze.com/shows/79/the-goldbergs
# https://www.tvmaze.com/shows/80/modern-family
# https://www.tvmaze.com/shows/81/criminal-minds
# https://www.tvmaze.com/shows/82/game-of-thrones
# https://www.tvmaze.com/shows/83/the-simpsons
# https://www.tvmaze.com/shows/84/family-guy
# https://www.tvmaze.com/shows/86/stalker
# https://www.tvmaze.com/shows/87/the-bridge
# https://www.tvmaze.com/shows/88/reign
# https://www.tvmaze.com/shows/89/unforgettable
# https://www.tvmaze.com/shows/90/haven
# https://www.tvmaze.com/shows/91/bad-judge
# https://www.tvmaze.com/shows/92/a-to-z
# https://www.tvmaze.com/shows/93/parenthood
# https://www.tvmaze.com/shows/94/defiance
# https://www.tvmaze.com/shows/95/falling-skies
# https://www.tvmaze.com/shows/96/manhattan-love-story
# https://www.tvmaze.com/shows/97/the-biggest-loser
# https://www.tvmaze.com/shows/98/scandal
# https://www.tvmaze.com/shows/99/americas-next-top-model
# https://www.tvmaze.com/shows/100/blue-bloods
# https://www.tvmaze.com/shows/101/the-good-wife
# https://www.tvmaze.com/shows/102/boardwalk-empire
# https://www.tvmaze.com/shows/103/law-order-special-victims-unit
# https://www.tvmaze.com/shows/104/dominion
# https://www.tvmaze.com/shows/105/from-dusk-till-dawn-the-series
# https://www.tvmaze.com/shows/106/justified
# https://www.tvmaze.com/shows/107/bobs-burgers
# https://www.tvmaze.com/shows/108/mulaney
# https://www.tvmaze.com/shows/109/csi-crime-scene-investigation
# https://www.tvmaze.com/shows/110/gracepoint
# https://www.tvmaze.com/shows/111/once-upon-a-time
# https://www.tvmaze.com/shows/112/south-park
# https://www.tvmaze.com/shows/114/survivor
# https://www.tvmaze.com/shows/115/king-of-the-hill
# https://www.tvmaze.com/shows/116/the-mentalist
# https://www.tvmaze.com/shows/117/star-wars-rebels
# https://www.tvmaze.com/shows/118/house
# https://www.tvmaze.com/shows/120/transparent
# https://www.tvmaze.com/shows/122/nikita
# https://www.tvmaze.com/shows/123/lost
# https://www.tvmaze.com/shows/124/2-broke-girls
# https://www.tvmaze.com/shows/125/selfie
# https://www.tvmaze.com/shows/126/mom
# https://www.tvmaze.com/shows/127/the-affair
# https://www.tvmaze.com/shows/128/jane-the-virgin
# https://www.tvmaze.com/shows/129/marry-me
# https://www.tvmaze.com/shows/130/two-and-a-half-men
# https://www.tvmaze.com/shows/131/about-a-boy
# https://www.tvmaze.com/shows/132/the-millers
# https://www.tvmaze.com/shows/133/elementary
# https://www.tvmaze.com/shows/134/heroes
# https://www.tvmaze.com/shows/136/the-mccarthys
# https://www.tvmaze.com/shows/137/cristela
# https://www.tvmaze.com/shows/138/the-leftovers
# https://www.tvmaze.com/shows/139/girls
# https://www.tvmaze.com/shows/140/looking
# https://www.tvmaze.com/shows/141/getting-on
# https://www.tvmaze.com/shows/142/veep
# https://www.tvmaze.com/shows/143/silicon-valley
# https://www.tvmaze.com/shows/144/the-comeback
# https://www.tvmaze.com/shows/145/house-of-lies
# https://www.tvmaze.com/shows/146/episodes
# https://www.tvmaze.com/shows/147/nurse-jackie
# https://www.tvmaze.com/shows/148/web-therapy
# https://www.tvmaze.com/shows/149/masters-of-sex
# https://www.tvmaze.com/shows/150/shameless
# https://www.tvmaze.com/shows/151/the-newsroom
# https://www.tvmaze.com/shows/152/ray-donovan
# https://www.tvmaze.com/shows/154/sanctuary
# https://www.tvmaze.com/shows/155/beauty-and-the-beast
# https://www.tvmaze.com/shows/156/twin-peaks
# https://www.tvmaze.com/shows/157/the-americans
# https://www.tvmaze.com/shows/158/fringe
# https://www.tvmaze.com/shows/159/state-of-affairs
# https://www.tvmaze.com/shows/160/weeds
# https://www.tvmaze.com/shows/161/dexter
# https://www.tvmaze.com/shows/162/carnivale
# https://www.tvmaze.com/shows/163/human-target
# https://www.tvmaze.com/shows/164/banshee
# https://www.tvmaze.com/shows/165/bionic-woman
# https://www.tvmaze.com/shows/166/battlestar-galactica
# https://www.tvmaze.com/shows/167/24
# https://www.tvmaze.com/shows/168/chuck
# https://www.tvmaze.com/shows/169/breaking-bad
# https://www.tvmaze.com/shows/170/orange-is-the-new-black
# https://www.tvmaze.com/shows/171/how-i-met-your-mother
# https://www.tvmaze.com/shows/172/suits
# https://www.tvmaze.com/shows/174/parks-and-recreation
# https://www.tvmaze.com/shows/175/house-of-cards
# https://www.tvmaze.com/shows/176/teen-wolf
# https://www.tvmaze.com/shows/177/pretty-little-liars
# https://www.tvmaze.com/shows/178/the-legend-of-korra
# https://www.tvmaze.com/shows/179/the-wire
# https://www.tvmaze.com/shows/180/firefly
# https://www.tvmaze.com/shows/181/extant
# https://www.tvmaze.com/shows/182/black-sails
# https://www.tvmaze.com/shows/183/tyrant
# https://www.tvmaze.com/shows/184/bojack-horseman
# https://www.tvmaze.com/shows/185/salem
# https://www.tvmaze.com/shows/186/turn-washingtons-spies
# https://www.tvmaze.com/shows/187/intelligence
# https://www.tvmaze.com/shows/188/believe
# https://www.tvmaze.com/shows/189/star-crossed
# https://www.tvmaze.com/shows/190/crisis
# https://www.tvmaze.com/shows/191/halt-and-catch-fire
# https://www.tvmaze.com/shows/192/hello-ladies
# https://www.tvmaze.com/shows/193/dads
# https://www.tvmaze.com/shows/194/hannibal
# https://www.tvmaze.com/shows/195/bates-motel
# https://www.tvmaze.com/shows/196/the-following
# https://www.tvmaze.com/shows/197/da-vincis-demons
# https://www.tvmaze.com/shows/198/the-fosters
# https://www.tvmaze.com/shows/199/mistresses
# https://www.tvmaze.com/shows/200/the-tomorrow-people
# https://www.tvmaze.com/shows/201/devious-maids
# https://www.tvmaze.com/shows/202/almost-human
# https://www.tvmaze.com/shows/203/the-carrie-diaries
# https://www.tvmaze.com/shows/204/stargate-sg-1
# https://www.tvmaze.com/shows/205/graceland
# https://www.tvmaze.com/shows/206/stargate-atlantis
# https://www.tvmaze.com/shows/207/stargate-universe
# https://www.tvmaze.com/shows/208/the-chair
# https://www.tvmaze.com/shows/209/survivors-remorse
# https://www.tvmaze.com/shows/210/doctor-who
# https://www.tvmaze.com/shows/211/666-park-avenue
# https://www.tvmaze.com/shows/212/alcatraz
# https://www.tvmaze.com/shows/213/the-gates
# https://www.tvmaze.com/shows/214/kingdom
# https://www.tvmaze.com/shows/215/american-dad
# https://www.tvmaze.com/shows/216/rick-and-morty
# https://www.tvmaze.com/shows/217/hostages
# https://www.tvmaze.com/shows/218/being-human
# https://www.tvmaze.com/shows/219/alphas
# https://www.tvmaze.com/shows/220/crossing-lines
# https://www.tvmaze.com/shows/221/rectify
# https://www.tvmaze.com/shows/222/happyland
# https://www.tvmaze.com/shows/224/twisted
# https://www.tvmaze.com/shows/225/ravenswood
# https://www.tvmaze.com/shows/226/the-crazy-ones
# https://www.tvmaze.com/shows/227/mob-city
# https://www.tvmaze.com/shows/228/last-resort
# https://www.tvmaze.com/shows/229/the-neighbors
# https://www.tvmaze.com/shows/230/go-on
# https://www.tvmaze.com/shows/231/vegas
# https://www.tvmaze.com/shows/232/the-river
# https://www.tvmaze.com/shows/233/awake
# https://www.tvmaze.com/shows/234/missing
# https://www.tvmaze.com/shows/235/the-new-normal
# https://www.tvmaze.com/shows/236/gcb
# https://www.tvmaze.com/shows/237/revolution
# https://www.tvmaze.com/shows/238/dallas
# https://www.tvmaze.com/shows/239/anger-management
# https://www.tvmaze.com/shows/240/cops
# https://www.tvmaze.com/shows/241/benched
# https://www.tvmaze.com/shows/242/the-great-fire
# https://www.tvmaze.com/shows/243/conan
# https://www.tvmaze.com/shows/244/strange-empire
# https://www.tvmaze.com/shows/245/town-of-the-living-dead
# https://www.tvmaze.com/shows/246/long-shadow
# https://www.tvmaze.com/shows/247/the-colbert-report
# https://www.tvmaze.com/shows/248/transporter-the-series
# https://www.tvmaze.com/shows/249/the-daily-show-with-jon-stewart

# %%
#Check if all lists return exactly 240 records
print(len(show_sum))
print(len(full_img))
print(len(med_img))
print(len(crtd_by))
print(len(rtng))
print(len(rtng_cnt))
# Out:
# 239
# 239
# 239
# 239
# 239
# 239

# %%
#Clean the Data remove the unwanted characters from the list
crtd_by = [s.replace("\n", "") for s in crtd_by]
print(crtd_by)
# Out:
# ['Stephen King', 'Jonathan Nolan', 'Grant RosenbergDaegan Fryklind', '', 'Nic Pizzolatto', '', 'Gideon Raff', 'Brad FalchukIan BrennanRyan Murphy', 'Mike Kelley', 'Stephen CarpenterDavid GreenwaltJim Kouf', 'Bruno Heller', 'Michelle Lovretta', '', 'Simon Barry', 'Daniel CeroneDavid S. Goyer', 'John Logan', 'Elise DoganieriBertram van Munster', 'Eric Kripke', 'Guillermo del ToroChuck Hogan', 'Hank SteinbergSteven Kane', 'Alan Ball', 'Edward KitsisAdam HorowitzJane EspensonZack Estrin', 'Leonard Freeman', '', 'Kohta Hirano', '', 'Tom Kapinos', 'Michael Hirst', 'Brad FalchukRyan Murphy', 'Joss WhedonJed WhedonMaurissa Tancharoen', 'Noah Hawley', 'Lee ShipmanBrian McGreevy', 'Cameron Porsandeh', '', 'Glen Morgan', 'Karl SchaeferCraig Engler', '', 'Takeshi ObataTsugumi Ooba', 'Jack Burditt', 'Len WisemanRoberto OrciAlex KurtzmanPhillip Iscove', '', '', 'Gary Glasberg', 'Matthew Miller', '', 'Barbara Hall', 'Dan GoorMichael Schur', 'Timothy J. Sexton', 'Jack AmielMichael Begler', 'Peter Nowalk', 'Callie Khouri', 'Howard Gordon', '', 'Dick WolfMatt Olmstead', 'Kenya Barris', 'Elizabeth Meriwether', 'Derek HaasMichael Brandt', 'Donald P. BellisarioDon McGill', 'John FawcettGraeme Manson', 'Julie Plec', 'Julie PlecKevin Williamson', 'Dennis Kelly', 'Hart Hanson', 'Chuck LorreBill Prady', 'Shonda Rhimes', 'Andrew W. Marlowe', 'Jon Bokenkamp', '', '', 'Shane Brennan', '', 'Tony GaytonJoe Gayton', '', 'Kurt Sutter', 'DeAnn HelineEileen Heisler', 'Jeff Rake', 'Adam F. Goldberg', 'Steven LevitanChristopher Lloyd', 'Jeff Davis', 'D.B. WeissDavid Benioff', 'Matt Groening', 'Seth MacFarlane', 'Kevin Williamson', '', 'Stephanie SenguptaLaurie McCarthy', '', 'Jim DunnSam Ernst', 'Anne HecheChad Kultgen', '', 'Jason Katims', "Rockne S. O'Bannon", 'Robert Rodat', 'Jeff Lowell', '', 'Shonda Rhimes', 'Tyra Banks', 'Mitchell BurgessRobin Green', 'Michelle KingRobert King', 'Terence Winter', 'Dick Wolf', 'Vaun Wilmott', 'Robert Rodriguez', 'Graham Yost', 'Jim DauteriveLoren Bouchard', '', 'Anthony E. Zuiker', 'Chris Chibnall', 'Edward KitsisAdam Horowitz', 'Trey ParkerMatt Stone', 'Charlie Parsons', 'Mike JudgeGreg Daniels', 'Bruno Heller', 'Dave FiloniSimon KinbergCarrie Beck', 'David Shore', 'Jill Soloway', 'Craig Silverstein', 'J.J. AbramsJeffrey LieberDamon Lindelof', 'Michael Patrick KingWhitney Cummings', 'Emily Kapnek', 'Chuck LorreEddie GorodetskyGemma Baker', 'Sarah TreemHagai Levi', '', 'David Caspe', 'Chuck LorreLee Aronsohn', '', 'Greg Garcia', 'Robert Doherty', 'Tim Kring', 'Brian Gallivan', '', 'Damon LindelofTom Perrotta', 'Lena Dunham', 'Michael Lannan', 'Mark V. OlsenVicki PepperdineJoanna ScanlanJo BrandWill Scheffer', 'Armando Iannucci', 'Mike JudgeJohn AltschulerDave Krinsky', 'Lisa KudrowMichael Patrick King', 'Matthew Carnahan', 'David CraneJeffrey Klarik', 'Evan DunskyLinda WallemLiz Brixius', 'Dan BucatinskyLisa KudrowDon Roos', 'Michelle Ashford', 'Paul Abbott', 'Aaron Sorkin', 'Ann Biderman', 'Damian Kindler', 'Jennifer LevinRon KoslowSherri Cooper-Landsman', 'David LynchMark Frost', 'Joe Weisberg', 'J.J. AbramsRoberto OrciAlex Kurtzman', 'Alexi Hawley', 'Jenji Kohan', 'James Manos, Jr.', 'Daniel Knauf', 'Jonathan E. Steinberg', 'Jonathan TropperDavid Schickler', 'Kenneth Johnson', 'Ronald D. MooreGlen A. Larson', 'Joel SurnowRobert Cochran', 'Chris FedakJosh Schwartz', 'Vince Gilligan', 'Jenji Kohan', 'Craig ThomasCarter Bays', 'Aaron Korsh', 'Michael SchurGreg Daniels', 'Beau Willimon', 'Jeff Davis', 'I. Marlene King', 'Bryan KonietzkoMichael Dante DiMartino', 'David Simon', 'Joss Whedon', 'Mickey Fisher', 'Jonathan E. SteinbergRobert Levine', 'Gideon Raff', 'Raphael Bob-Waksberg', 'Brannon BragaAdam S. Simon', 'Craig Silverstein', 'Michael Seitzman', 'Alfonso CuarónMark Friedman', '', 'Rand Ravich', 'Christopher CantwellChristopher C. Rogers', 'Stephen MerchantGene StupnitskyLee Eisenberg', 'Wellesley WildAlec Sulkin', '', '', 'Kevin Williamson', 'David S. Goyer', 'Peter PaigeBradley Bredeweg', 'K.J. Steinberg', '', 'Marc  ...

# %%
#Add these new columns to the existing DataFrame.
df['Summary'] = show_sum
df['Full Img'] = full_img
df['Med img'] = med_img
df['Created By'] = crtd_by
df['Ratings'] = rtng
df['Ratings Count'] = rtng_cnt
df.head()
# Out:
#                                                              Show URL  \
# name
# Under the Dome          https://www.tvmaze.com/shows/1/under-the-dome
# Person of Interest  https://www.tvmaze.com/shows/2/person-of-interest
# Bitten                          https://www.tvmaze.com/shows/3/bitten
# Arrow                            https://www.tvmaze.com/shows/4/arrow
# True Detective          https://www.tvmaze.com/shows/5/true-detective
#
#                    Show Type Language                              Genres  \
# name
# Under the Dome      Scripted  English  [Drama, Science-Fiction, Thriller]
# Person of Interest  Scripted  English    [Action, Crime, Science-Fiction]
# Bitten              Scripted  English            [Drama, Horror, Romance]
# Arrow               Scripted  English    [Drama, Action, Science-Fiction]
# True Detective      Scripted  English            [Drama, Crime, Thriller]
#
#                      Status Runtime Premiere Date  \
# name
# Under the Dome        Ended      60    2013-06-24
# Person of Interest    Ended      60    2011-09-22
# Bitten                Ended      60    2014-01-11
# Arrow                 Ended      60    2012-10-10
# True Detective      Running      60    2014-01-12
#
#                                                    Official Site   Time  \
# name
# Under the Dome          http://www.cbs.com/shows/under-the-dome/  22:00
# Person of Interest  http://www.cbs.com/shows/person_of_interest/  22:00
# Bitten                                   http://bitten.space.ca/  22:00
# Arrow                            http://www.cwtv.com/shows/arrow  21:00
# True Detective                 http://www.hbo.com/true-detective  21:00
#
#                            Day             Network        Country  \
# name
# Under the Dome      [Thursday]                 CBS  United States
# Person of Interest   [Tuesday]                 CBS  United States
# Bitten                [Friday]  CTV Sci-Fi Channel         Canada
# Arrow                [Tuesday]              The CW  United States
# True Detective        [Sunday]                 HBO  United States
#
#                    Country Code          Timezone  \
# name
# Under the Dome               US  America/New_York
# Person of Interest           US  America/New_York
# Bitten                       CA   America/Halifax
# Arrow                        US  America/New_York
# True Detective               US  America/New_York
#
#                                                               Summary  \
# name
# Under the Dome      Under the Dome is the story of a small town th...
# Person of Interest  You are being watched. The government has a se...
# Bitten              Based on the critically acclaimed series of no...
# Arrow               After a violent shipwreck, billionaire playboy...
# True Detective      Touch darkness and darkness touches you back. ...
#
#                                                              Full Img  \
# name
# Under the Dome      http://static.tvmaze.com/uploads/images/origin...
# Person of Interest  http://static.tvmaze.com/uploads/images/origin...
# Bitten              http://static.tvmaze.com/uploads/images/origin...
# Arrow               http://static.tvmaze.com/uploads/images/origin...
# True Detective      http://static.tvmaze.com/uploads/images/origin...
#
#                                                               Med img  \
# name
# Under the Dome      //static.tvmaze.com/uploads/images/medium_port...
# Person of Interest  //static.tvmaze.com/uploads/images/medium_port...
# Bitten              //static.tvmaze.com/uploads/images/medium_port...
# Arrow               //static.tvmaze.com/uploads/images/medium_port...
# True Detective      //static.tvmaze.com/uploads/images/medium_port...
#
#                                         Created By Ratings Ratings Count
# name
# Under the Dome                        Stephen King     6.6           218
# Person of Interest                  Jonathan Nolan     8.9           317
# Bitten              Grant RosenbergDaegan Fryklind     7.5            80
# Arrow                                                  7.4           488
# True Detective                      Nic Pizzolatto     8.3           298

# %%
#Again Replace the empty data values to for new columns to 'NA', which were not avaiable 
df.replace('','NA', inplace=True)

# %%
#Generate the output of api + webscrapping
df.to_csv('Output/tvmaze_api_webscrape_output.csv', encoding='utf-8')

# %%
#Read a CSV with data of TV shows

# %%
df_csv = pd.read_csv('Resources/TV_Shows.csv',encoding = "utf-8")
df_csv = df_csv[['name','release_year','duration','cast']]
df_csv.head()
# Out:
#     name  release_year   duration  \
# 0     3%          2020  4 Seasons
# 1   7:19          2016     93 min
# 2  23:59          2011     78 min
# 3      9          2009     80 min
# 4     21          2008    123 min
#
#                                                 cast
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...

# %%
df.head()
# Out:
#                                                              Show URL  \
# name
# Under the Dome          https://www.tvmaze.com/shows/1/under-the-dome
# Person of Interest  https://www.tvmaze.com/shows/2/person-of-interest
# Bitten                          https://www.tvmaze.com/shows/3/bitten
# Arrow                            https://www.tvmaze.com/shows/4/arrow
# True Detective          https://www.tvmaze.com/shows/5/true-detective
#
#                    Show Type Language                              Genres  \
# name
# Under the Dome      Scripted  English  [Drama, Science-Fiction, Thriller]
# Person of Interest  Scripted  English    [Action, Crime, Science-Fiction]
# Bitten              Scripted  English            [Drama, Horror, Romance]
# Arrow               Scripted  English    [Drama, Action, Science-Fiction]
# True Detective      Scripted  English            [Drama, Crime, Thriller]
#
#                      Status Runtime Premiere Date  \
# name
# Under the Dome        Ended      60    2013-06-24
# Person of Interest    Ended      60    2011-09-22
# Bitten                Ended      60    2014-01-11
# Arrow                 Ended      60    2012-10-10
# True Detective      Running      60    2014-01-12
#
#                                                    Official Site   Time  \
# name
# Under the Dome          http://www.cbs.com/shows/under-the-dome/  22:00
# Person of Interest  http://www.cbs.com/shows/person_of_interest/  22:00
# Bitten                                   http://bitten.space.ca/  22:00
# Arrow                            http://www.cwtv.com/shows/arrow  21:00
# True Detective                 http://www.hbo.com/true-detective  21:00
#
#                            Day             Network        Country  \
# name
# Under the Dome      [Thursday]                 CBS  United States
# Person of Interest   [Tuesday]                 CBS  United States
# Bitten                [Friday]  CTV Sci-Fi Channel         Canada
# Arrow                [Tuesday]              The CW  United States
# True Detective        [Sunday]                 HBO  United States
#
#                    Country Code          Timezone  \
# name
# Under the Dome               US  America/New_York
# Person of Interest           US  America/New_York
# Bitten                       CA   America/Halifax
# Arrow                        US  America/New_York
# True Detective               US  America/New_York
#
#                                                               Summary  \
# name
# Under the Dome      Under the Dome is the story of a small town th...
# Person of Interest  You are being watched. The government has a se...
# Bitten              Based on the critically acclaimed series of no...
# Arrow               After a violent shipwreck, billionaire playboy...
# True Detective      Touch darkness and darkness touches you back. ...
#
#                                                              Full Img  \
# name
# Under the Dome      http://static.tvmaze.com/uploads/images/origin...
# Person of Interest  http://static.tvmaze.com/uploads/images/origin...
# Bitten              http://static.tvmaze.com/uploads/images/origin...
# Arrow               http://static.tvmaze.com/uploads/images/origin...
# True Detective      http://static.tvmaze.com/uploads/images/origin...
#
#                                                               Med img  \
# name
# Under the Dome      //static.tvmaze.com/uploads/images/medium_port...
# Person of Interest  //static.tvmaze.com/uploads/images/medium_port...
# Bitten              //static.tvmaze.com/uploads/images/medium_port...
# Arrow               //static.tvmaze.com/uploads/images/medium_port...
# True Detective      //static.tvmaze.com/uploads/images/medium_port...
#
#                                         Created By Ratings Ratings Count
# name
# Under the Dome                        Stephen King     6.6           218
# Person of Interest                  Jonathan Nolan     8.9           317
# Bitten              Grant RosenbergDaegan Fryklind     7.5            80
# Arrow                                           NA     7.4           488
# True Detective                      Nic Pizzolatto     8.3           298

# %%
#Merge this data with the existing api and scrapping data
#New columns (Netflix release year, Duration, cast) from the CSV are fetched
#These details are merged with previous DF on 'Name of the Show'

merged_df = pd.merge(df, df_csv, on='name', how='left')
merged_df.head()
# Out:
#                  name                                           Show URL  \
# 0      Under the Dome      https://www.tvmaze.com/shows/1/under-the-dome
# 1  Person of Interest  https://www.tvmaze.com/shows/2/person-of-interest
# 2              Bitten              https://www.tvmaze.com/shows/3/bitten
# 3               Arrow               https://www.tvmaze.com/shows/4/arrow
# 4      True Detective      https://www.tvmaze.com/shows/5/true-detective
#
#   Show Type Language                              Genres   Status Runtime  \
# 0  Scripted  English  [Drama, Science-Fiction, Thriller]    Ended      60
# 1  Scripted  English    [Action, Crime, Science-Fiction]    Ended      60
# 2  Scripted  English            [Drama, Horror, Romance]    Ended      60
# 3  Scripted  English    [Drama, Action, Science-Fiction]    Ended      60
# 4  Scripted  English            [Drama, Crime, Thriller]  Running      60
#
#   Premiere Date                                 Official Site   Time  ...  \
# 0    2013-06-24      http://www.cbs.com/shows/under-the-dome/  22:00  ...
# 1    2011-09-22  http://www.cbs.com/shows/person_of_interest/  22:00  ...
# 2    2014-01-11                       http://bitten.space.ca/  22:00  ...
# 3    2012-10-10               http://www.cwtv.com/shows/arrow  21:00  ...
# 4    2014-01-12             http://www.hbo.com/true-detective  21:00  ...
#
#            Timezone                                            Summary  \
# 0  America/New_York  Under the Dome is the story of a small town th...
# 1  America/New_York  You are being watched. The government has a se...
# 2   America/Halifax  Based on the critically acclaimed series of no...
# 3  America/New_York  After a violent shipwreck, billionaire playboy...
# 4  America/New_York  Touch darkness and darkness touches you back. ...
#
#                                             Full Img  \
# 0  http://static.tvmaze.com/uploads/images/origin...
# 1  http://static.tvmaze.com/uploads/images/origin...
# 2  http://static.tvmaze.com/uploads/images/origin...
# 3  http://static.tvmaze.com/uploads/images/origin...
# 4  http://static.tvmaze.com/uploads/images/origin...
#
#                                              Med img  \
# 0  //static.tvmaze.com/uploads/images/medium_port...
# 1  //static.tvmaze.com/uploads/images/medium_port...
# 2  //static.tvmaze.com/uploads/images/medium_port...
# 3  //static.tvmaze.com/uploads/images/medium_port...
# 4  //static.tvmaze.com/uploads/images/medium_port...
#
#                        Created By Ratings Ratings Count release_year  \
# 0                    Stephen King     6.6           218          NaN
# 1                  Jonathan Nolan     8.9           317       2016.0
# 2  Grant RosenbergDaegan Fryklind     7.5            80       2016.0
# 3                              NA     7.4           488       2019.0
# 4                  Nic Pizzolatto     8.3           298          NaN
#
#     duration                                               cast
# 0        NaN                                                NaN
# 1  5 Seasons  Jim Caviezel, Michael Emerson, Taraji P. Henso...
# 2  3 Seasons  Laura Vandervoort, Greyston Holt, Greg Bryk, S...
# 3  8 Seasons  Stephen Amell, Katie Cassidy, David Ramsey, Wi...
# 4        NaN                                                NaN
#
# [5 rows x 24 columns]

# %%
#Again Replace the empty data values to for new columns to 'NA', which were not avaiable 
merged_df.replace(np.NAN,'NA', inplace=True)

# %%
merged_df.to_csv('Output/TVShows_final_output.csv', encoding='utf-8')

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.TVShows_db
collection = db.items

# %%
#Check if collection exists, if does then drop
results = collection.find()
if results.count() >= 1:
    collection.drop()
# Out:
# <ipython-input-30-cd753509ce21>:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   if results.count() >= 1:

# %%
collection.insert_many(merged_df.to_dict('records'))

# %%
results = collection.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6084e305273769203de55296'), 'name': 'Under the Dome', 'Show URL': 'https://www.tvmaze.com/shows/1/under-the-dome', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Science-Fiction', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2013-06-24', 'Official Site': 'http://www.cbs.com/shows/under-the-dome/', 'Time': '22:00', 'Day': ['Thursday'], 'Network': 'CBS', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Under the Dome is the story of a small town that is suddenly and inexplicably sealed off from the rest of the world by an enormous transparent dome. The town's inhabitants must deal with surviving the post-apocalyptic conditions while searching for answers about the dome, where it came from and if and when it will go away.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/81/202627.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/81/202627.jpg', 'Created By': 'Stephen King', 'Ratings': '6.6', 'Ratings Count': '218', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55297'), 'name': 'Person of Interest', 'Show URL': 'https://www.tvmaze.com/shows/2/person-of-interest', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Crime', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2011-09-22', 'Official Site': 'http://www.cbs.com/shows/person_of_interest/', 'Time': '22:00', 'Day': ['Tuesday'], 'Network': 'CBS', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'You are being watched. The government has a secret system, a machine that spies on you every hour of every day. I know because I built it. I designed the Machine to detect acts of terror but it sees everything. Violent crimes involving ordinary people. People like you. Crimes the government considered "irrelevant". They wouldn\'t act so I decided I would. But I needed a partner. Someone with the skills to intervene. Hunted by the authorities, we work in secret. You\'ll never find us. But victim or perpetrator, if your number is up, we\'ll find you.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/163/407679.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/163/407679.jpg', 'Created By': 'Jonathan Nolan', 'Ratings': '8.9', 'Ratings Count': '317', 'release_year': 2016.0, 'duration': '5 Seasons', 'cast': 'Jim Caviezel, Michael Emerson, Taraji P. Henson, Kevin Chapman, Sarah Shahi, Amy Acker'}
# {'_id': ObjectId('6084e305273769203de55298'), 'name': 'Bitten', 'Show URL': 'https://www.tvmaze.com/shows/3/bitten', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Horror', 'Romance'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-01-11', 'Official Site': 'http://bitten.space.ca/', 'Time': '22:00', 'Day': ['Friday'], 'Network': 'CTV Sci-Fi Channel', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': 'Based on the critically acclaimed series of novels from Kelley Armstrong. Set in Toronto and upper New York State, Bitten follows the adventures of 28-year-old Elena Michaels, the world\'s only female werewolf. An orphan, Elena thought she finally found her "happily ever after" with her new love Clayton, until her life changed forever. With one small bite, the normal life she craved was taken away and she was left to survive life with the Pack.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/15.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/15.jpg', 'Created By': 'Grant RosenbergDaegan Fryklind', 'Ratings': '7.5', 'Ratings Count': '80', 'release_year': 2016.0, 'duration': '3 Seasons', 'cast': 'Laura Vandervoort, Greyston Holt, Greg Bryk, Steve Lund, Paul Greene, Michael Xavier, Genelle Williams'}
# {'_id': ObjectId('6084e305273769203de55299'), 'name': 'Arrow', 'Show URL': 'https://www.tvmaze.com/shows/4/arrow', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2012-10-10', 'Official Site': 'http://www.cwtv.com/shows/arrow', 'Time': '21:00', 'Day': ['Tuesday'], 'Network': 'The CW', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'After a violent shipwreck, billionaire playboy Oliver Queen was missing and presumed dead for five years before being discovered alive on a remote island in the Pacific. He returned home to Starling City, welcomed by his devoted mother Moira, beloved sister Thea and former flame Laurel Lance. With the aid of his trusted chauffeur/bodyguard John Diggle, the computer-hacking skills of Felicity Smoak and the occasional, reluctant assistance of former police detective, now beat cop, Quentin Lance, Oliver has been waging a one-man war on crime.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/213/534017.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/213/534017.jpg', 'Created By': 'NA', 'Ratings': '7.4', 'Ratings Count': '488', 'release_year': 2019.0, 'duration': '8 Seasons', 'cast': 'Stephen Amell, Katie Cassidy, David Ramsey, Willa Holland, Paul Blackthorne, Emily Bett Rickards, John Barrowman, Colton Haynes, Susanna Thompson, Anna Hopkins, Juliana Harkavy, Adrian Holmes, Kathleen Gati, Echo Kellum, Rick Gonzalez, Dominic Bogart, Manu Bennett'}
# {'_id': ObjectId('6084e305273769203de5529a'), 'name': 'True Detective', 'Show URL': 'https://www.tvmaze.com/shows/5/true-detective', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Crime', 'Thriller'], 'Status': 'Running', 'Runtime': 60.0, 'Premiere Date': '2014-01-12', 'Official Site': 'http://www.hbo.com/true-detective', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'HBO', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Touch darkness and darkness touches you back. True Detective centers on troubled cops and the investigations that drive them to the edge. Each season features a new cast and a new case.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/178/445621.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/178/445621.jpg', 'Created By': 'Nic Pizzolatto', 'Ratings': '8.3', 'Ratings Count': '298', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5529b'), 'name': 'The 100', 'Show URL': 'https://www.tvmaze.com/shows/6/the-100', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Adventure', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-03-19', 'Official Site': 'http://www.cwtv.com/shows/the-100/', 'Time': '20:00', 'Day': ['Wednesday'], 'Network': 'The CW', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Ninety-seven years ago, nuclear Armageddon decimated planet Earth, destroying civilization. The only survivors were the 400 inhabitants of 12 international space stations that were in orbit at the time. Three generations have been born in space, the survivors now number 4,000, and resources are running out on their dying "Ark" - the 12 stations now linked together and repurposed to keep the survivors alive. Draconian measures including capital punishment and population control are the order of the day, as the leaders of the Ark take ruthless steps to ensure their future, including secretly exiling a group of 100 juvenile prisoners to the Earth\'s surface to test whether it\'s habitable.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/257/642675.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/257/642675.jpg', 'Created By': 'NA', 'Ratings': '7.7', 'Ratings Count': '427', 'release_year': 2020.0, 'duration': '7 Seasons', 'cast': 'Eliza Taylor, Paige Turco, Bob Morley, Marie Avgeropoulos, Christopher Larkin, Henry Ian Cusick, Isaiah Washington, Lindsey Morgan, Devon Bostick, Richard Harmon, Ricky Whittle, Jarod Joseph, Chelsey Reist, Sachin Sahel, Adina Porter'}
# {'_id': ObjectId('6084e305273769203de5529c'), 'name': 'Homeland', 'Show URL': 'https://www.tvmaze.com/shows/7/homeland', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Thriller', 'Espionage'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2011-10-02', 'Official Site': 'http://www.sho.com/sho/homeland/home', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'Showtime', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'The winner of 6 Emmy Awards including Outstanding Drama Series, Homeland is an edge-of-your-seat sensation. Marine Sergeant Nicholas Brody is both a decorated hero and a serious threat. CIA officer Carrie Mathison is tops in her field despite being bipolar. The delicate dance these two complex characters perform, built on lies, suspicion, and desire, is at the heart of this gripping, emotional thriller in which nothing short of the fate of our nation is at stake.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/230/575652.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/230/575652.jpg', 'Created By': 'Gideon Raff', 'Ratings': '8.2', 'Ratings Count': '365', 'release_year': 2019.0, 'duration': '73 min', 'cast': 'Parambrata Chatterjee, Ani Hovhannisyan, Jonathan Dumontier, Varzu, Sylvie de Neef, Prakashchandra Roy, Nicolas Pierson, Anahit Simonyan'}
# {'_id': ObjectId('6084e305273769203de5529d'), 'name': 'Glee', 'Show URL': 'https://www.tvmaze.com/shows/8/glee', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Music', 'Romance'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2009-05-19', 'Official Site': 'http://www.fox.com/glee', 'Time': '21:00', 'Day': ['Tuesday'], 'Network': 'FOX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Glee is a musical comedy about a group of ambitious and talented young adults in search of strength, acceptance and, ultimately, their voice.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/73.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/73.jpg', 'Created By': 'Brad FalchukIan BrennanRyan Murphy', 'Ratings': '6.7', 'Ratings Count': '57', 'release_year': 2015.0, 'duration': '6 Seasons', 'cast': 'Lea Michele, Chris Colfer, Jane Lynch, Matthew Morrison, Cory Monteith, Naya Rivera, Kevin McHale, Jenna Ushkowitz, Amber Riley, Mark Salling, Heather Morris, Harry Shum Jr., Jayma Mays, Dianna Agron'}
# {'_id': ObjectId('6084e305273769203de5529e'), 'name': 'Revenge', 'Show URL': 'https://www.tvmaze.com/shows/9/revenge', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Thriller', 'Mystery'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2011-09-21', 'Official Site': 'NA', 'Time': '22:00', 'Day': ['Sunday'], 'Network': 'ABC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'This is not a story about forgiveness; Revenge is a show about retribution. Meet Emily Thorne, the newest resident of The Hamptons. When she was a little girl (and known as Amanda Clarke) her father, David Clarke, was framed for a horrific crime and subsequently sent to prison. While serving his time, the conspirators plotted and murdered David in order to prevent the truth from coming out. Emily is now back with a new identity and ready to take vengeance on the people that murdered her father and stole her childhood.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/82/206879.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/82/206879.jpg', 'Created By': 'Mike Kelley', 'Ratings': '7.8', 'Ratings Count': '78', 'release_year': 2017.0, 'duration': '1 Season', 'cast': 'Lalita Panyopas, Saksit Tangtong, Tao Somchai Khemklad, Tack Parunyu Rojanawuttitum, Pongsatorn Jongwilas, Chaleumpol Tikumpornteerawong, Akarin Akaranitimaytharatt, Kanthi Pitithan, Plerng Pollapakk Vacharaponghiran, Kritteera Inpornwijit'}
# {'_id': ObjectId('6084e305273769203de5529f'), 'name': 'Grimm', 'Show URL': 'https://www.tvmaze.com/shows/10/grimm', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Crime', 'Supernatural'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2011-10-28', 'Official Site': 'http://www.nbc.com/grimm', 'Time': '20:00', 'Day': ['Friday'], 'Network': 'NBC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Grimm is a drama series inspired by the classic Grimm Brothers\' Fairy Tales. After Portland homicide detective Nick Burkhardt discovers he\'s descended from an elite line of criminal profilers known as "Grimms", he increasingly finds his responsibilities as a detective at odds with his new responsibilities as a Grimm.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/69/174906.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/69/174906.jpg', 'Created By': 'Stephen CarpenterDavid GreenwaltJim Kouf', 'Ratings': '8.5', 'Ratings Count': '241', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552a0'), 'name': 'Gotham', 'Show URL': 'https://www.tvmaze.com/shows/11/gotham', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Crime'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-09-22', 'Official Site': 'http://www.fox.com/gotham', 'Time': '20:00', 'Day': ['Thursday'], 'Network': 'FOX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'The good. The evil. The beginning.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/189/474715.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/189/474715.jpg', 'Created By': 'Bruno Heller', 'Ratings': '7.7', 'Ratings Count': '328', 'release_year': 2019.0, 'duration': '5 Seasons', 'cast': 'Ben McKenzie, Donal Logue, Jada Pinkett Smith, David Mazouz, Sean Pertwee, Camren Bicondova, Robin Lord Taylor, Cory Michael Smith, Erin Richards, John Doman, Victoria Cartagena, Andrew Stewart-Jones, Larry Pine, Jessica Lucas, Maggie Geha, Charlie Tahan, Drew Powell, Morena Baccarin, Anthony Carrigan, Crystal Reed, Chris Chalk, Damian Young, Michael Buscemi, Alexander Siddig, Michael Maize'}
# {'_id': ObjectId('6084e305273769203de552a1'), 'name': 'Lost Girl', 'Show URL': 'https://www.tvmaze.com/shows/12/lost-girl', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Fantasy', 'Horror'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2010-09-12', 'Official Site': 'http://www.showcase.ca/lostgirl', 'Time': '22:00', 'Day': ['Sunday'], 'Network': 'Showcase', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': 'Lost Girl follows supernatural seductress Bo, a Succubus who feeds on the sexual energy of humans. Growing up with human parents, Bo had no reason to believe she was anything other than the girl next door — until she drained her boyfriend to death in their first sexual encounter. Now she has hit the road alone and afraid.  She discovers she is one of the Fae, creatures of legend and folklore, who pass as humans while feeding off them secretly and in different ways, as they have for millennia. Relieved yet horrified to find out that she is not alone, Bo decides to take the middle path between the humans and the Fae while embarking on a personal mission to unlock the secrets of her origin.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/137.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/137.jpg', 'Created By': 'Michelle Lovretta', 'Ratings': '8.1', 'Ratings Count': '95', 'release_year': 2015.0, 'duration': '5 Seasons', 'cast': 'Anna Silk, Kris Holden-Ried, Ksenia Solo, Richard Howland, Zoie Palmer, K.C. Collins'}
# {'_id': ObjectId('6084e305273769203de552a2'), 'name': 'The Flash', 'Show URL': 'https://www.tvmaze.com/shows/13/the-flash', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Science-Fiction'], 'Status': 'Running', 'Runtime': 60.0, 'Premiere Date': '2014-10-07', 'Official Site': 'http://www.cwtv.com/shows/the-flash/', 'Time': '20:00', 'Day': ['Tuesday'], 'Network': 'The CW', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'After a particle accelerator causes a freak storm, CSI Investigator Barry Allen is struck by lightning and falls into a coma. Months later he awakens with the power of super speed, granting him the ability to move through Central City like an unseen guardian angel. Though initially excited by his newfound powers, Barry is shocked to discover he is not the only "meta-human" who was created in the wake of the accelerator explosion -- and not everyone is using their new powers for good. Barry partners with S.T.A.R. Labs and dedicates his life to protect the innocent. For now, only a few close friends and associates know that Barry is literally the fastest man alive, but it won\'t be long before the world learns what Barry Allen has become...The Flash!', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/296/740329.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/296/740329.jpg', 'Created By': 'NA', 'Ratings': '7.8', 'Ratings Count': '517', 'release_year': 2019.0, 'duration': '6 Seasons', 'cast': 'Grant Gustin, Candice Patton, Danielle Panabaker, Carlos Valdes, Tom Cavanagh, Jesse L. Martin, Neil Sandilands, Britne Oldford, Danielle Nicolet, Keiynan Lonsdale, Kim Engelbrecht'}
# {'_id': ObjectId('6084e305273769203de552a3'), 'name': 'Continuum', 'Show URL': 'https://www.tvmaze.com/shows/14/continuum', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Crime', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2012-05-27', 'Official Site': 'http://www.showcase.ca/Continuum', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'Showcase', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': 'Continuum is a one-hour police drama centered on Kiera Cameron, a regular cop from 65 years in the future who finds herself trapped in present day Vancouver. She is alone, a stranger in a strange land, and has eight of the most ruthless criminals from the future, known as Liber8, loose in the city.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/184.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/184.jpg', 'Created By': 'Simon Barry', 'Ratings': '8.2', 'Ratings Count': '180', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552a4'), 'name': 'Constantine', 'Show URL': 'https://www.tvmaze.com/shows/15/constantine', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Horror'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-10-24', 'Official Site': 'https://www.nbc.com/constantine', 'Time': '20:00', 'Day': ['Friday'], 'Network': 'NBC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Based on the wildly popular comic book series "Hellblazer" from DC Comics, seasoned demon hunter and master of the occult John Constantine is armed with a ferocious knowledge of the dark arts and a wickedly naughty wit. He fights the good fight - or at least he did. With his soul already damned to hell, he\'s decided to abandon his campaign against evil until a series of events thrusts him back into the fray, and he\'ll do whatever it takes to protect the innocent. With the balance of good and evil on the line\u200e, Constantine will use his skills to travel the country, find the supernatural terrors that threaten our world and send them back where they belong. After that, who knows... maybe there\'s hope for him and his soul after all.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/154.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/154.jpg', 'Created By': 'Daniel CeroneDavid S. Goyer', 'Ratings': '7.5', 'Ratings Count': '138', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552a5'), 'name': 'Penny Dreadful', 'Show URL': 'https://www.tvmaze.com/shows/16/penny-dreadful', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Horror', 'Thriller', 'Supernatural'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-05-11', 'Official Site': 'http://www.sho.com/penny-dreadful', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'Showtime', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Some of literature's most terrifying characters, including Dr. Frankenstein and his monster, Dorian Gray, and iconic figures from the novel Dracula are lurking in the darkest corners of Victorian London. They are joined by a core of original characters in a complex, frightening new narrative. Penny Dreadful is a psychological thriller filled with dark mystery and suspense, where personal demons from the past can be stronger than vampires, evil spirits and immortal beasts.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/48/122260.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/48/122260.jpg', 'Created By': 'John Logan', 'Ratings': '8.3', 'Ratings Count': '182', 'release_year': 2016.0, 'duration': '3 Seasons', 'cast': 'Josh Hartnett, Eva Green, Timothy Dalton, Reeve Carney, Rory Kinnear, Billie Piper, Danny Sapani, Harry Treadaway'}
# {'_id': ObjectId('6084e305273769203de552a6'), 'name': 'The Amazing Race', 'Show URL': 'https://www.tvmaze.com/shows/18/the-amazing-race', 'Show Type': 'Reality', 'Language': 'English', 'Genres': ['Action', 'Adventure', 'Family'], 'Status': 'Running', 'Runtime': 60.0, 'Premiere Date': '2001-09-05', 'Official Site': 'http://www.cbs.com/shows/amazing_race/', 'Time': '20:00', 'Day': ['Wednesday'], 'Network': 'CBS', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'From athletes and actors to tattoo artists, social workers and musicians - a diverse mix of teams will need to utilize their street smarts and savvy know-how to compete in the race of their lifetime.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/237/592579.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/237/592579.jpg', 'Created By': 'Elise DoganieriBertram van Munster', 'Ratings': '7.8', 'Ratings Count': '28', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552a7'), 'name': 'Supernatural', 'Show URL': 'https://www.tvmaze.com/shows/19/supernatural', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Supernatural'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2005-09-13', 'Official Site': 'http://www.cwtv.com/shows/supernatural', 'Time': '20:00', 'Day': ['Thursday'], 'Network': 'The CW', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "This haunting series follows the Winchester brothers as they crisscross the lonely and mysterious back roads of the country in their '67 Chevy Impala, hunting down every evil supernatural force they encounter along the way.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/268/672051.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/268/672051.jpg', 'Created By': 'Eric Kripke', 'Ratings': '8.4', 'Ratings Count': '412', 'release_year': 2019.0, 'duration': '15 Seasons', 'cast': 'Jared Padalecki, Jensen Ackles, Mark Sheppard, Misha Collins, Jim Beaver, Andrea Menard, Samantha Smith, Mark Pellegrino, Alexander Calvert'}
# {'_id': ObjectId('6084e305273769203de552a8'), 'name': 'The Strain', 'Show URL': 'https://www.tvmaze.com/shows/20/the-strain', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Horror', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-07-13', 'Official Site': 'http://www.fxnetworks.com/thestrain', 'Time': '22:00', 'Day': ['Sunday'], 'Network': 'FX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'The Strain is a high-concept thriller that tells the story of Dr. Ephraim Goodweather, the head of the Center for Disease Control Canary Team in New York City. He and his team are called upon to investigate a mysterious viral outbreak with hallmarks of an ancient and evil strain of vampirism. As the strain spreads, Goodweather, his team, and an assembly of everyday New Yorkers wage war for the fate of humanity itself.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/70/175363.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/70/175363.jpg', 'Created By': 'Guillermo del ToroChuck Hogan', 'Ratings': '7.5', 'Ratings Count': '207', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552a9'), 'name': 'The Last Ship', 'Show URL': 'https://www.tvmaze.com/shows/21/the-last-ship', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-06-22', 'Official Site': 'http://www.tntdrama.com/shows/the-last-ship', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'TNT', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Their mission is simple: Find a cure. Stop the virus. Save the world. When a global pandemic wipes out eighty percent of the planet's population, the crew of a lone and unaffected Navy destroyer, the USS Nathan James, must find a way to pull humanity from the brink of extinction.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/164/412464.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/164/412464.jpg', 'Created By': 'Hank SteinbergSteven Kane', 'Ratings': '7.6', 'Ratings Count': '225', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552aa'), 'name': 'True Blood', 'Show URL': 'https://www.tvmaze.com/shows/22/true-blood', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Romance', 'Supernatural'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2008-09-07', 'Official Site': 'http://www.hbo.com/true-blood', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'HBO', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'True Blood is a horror/drama based on a series of novels called The Southern American Vampires Mysteries. It focuses on Sookie Stackhouse and her various encounters with vampires and other supernatural beings. The show is centred in the small town of Bon Temps in Louisiana. The show focuses heavily on the co-existence of humans with vampires. The show also touches on several other controversial issues involving equal rights, violence, discrimination and religion.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/236/590987.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/236/590987.jpg', 'Created By': 'Alan Ball', 'Ratings': '7.9', 'Ratings Count': '148', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552ab'), 'name': 'Once Upon a Time in Wonderland', 'Show URL': 'https://www.tvmaze.com/shows/23/once-upon-a-time-in-wonderland', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Adventure', 'Fantasy'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2013-10-10', 'Official Site': 'NA', 'Time': '20:00', 'Day': ['Thursday'], 'Network': 'ABC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "In Victorian England, the young and beautiful Alice tells a tale of a strange new land that exists on the other side of a rabbit hole. An invisible cat, a hookah smoking caterpillar and playing-cards that talk are just some of the fantastic things she's seen during this impossible adventure. Surely this troubled girl must be insane, and her doctors aim to cure her with a treatment that will make her forget everything. Alice seems ready to put it all behind her, especially the painful memory of the genie she fell in love with and lost forever -- the handsome and mysterious Cyrus . But deep down Alice knows this world is real, and just in the nick of time the sardonic Knave of Hearts and the irrepressible White Rabbit arrive to save her from a doomed fate. Together the trio will take a tumble down the rabbit hole to this Wonderland where nothing is impossible.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/73/183661.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/73/183661.jpg', 'Created By': 'Edward KitsisAdam HorowitzJane EspensonZack Estrin', 'Ratings': '6.7', 'Ratings Count': '40', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552ac'), 'name': 'Hawaii Five-0', 'Show URL': 'https://www.tvmaze.com/shows/24/hawaii-five-0', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'Crime'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2010-09-20', 'Official Site': 'http://www.cbs.com/shows/hawaii_five_0/', 'Time': '21:00', 'Day': ['Friday'], 'Network': 'CBS', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Hawaii Five-0 is a contemporary take on the classic series about a new elite federalized task force whose mission is to wipe out the crime that washes up on the Islands\' sun-drenched beaches. Detective Steve McGarrett, a decorated Naval officer-turned-cop, returned to Oahu to investigate his father\'s murder and stayed after Hawaii\'s former governor persuaded him to head up the new team: his rules, no red tape and full blanket authority to hunt down the biggest "game" in town. Joining McGarrett is Detective Danny "Danno" Williams, a relocated ex-New Jersey cop - a working man in paradise who prefers skyscrapers to the coastline - but who\'s committed to keeping the Islands safe for his young daughter; Chin Ho Kelly, an ex-Honolulu police detective and former protégé of McGarrett\'s father who was wrongly accused of corruption; Dr. Max Bergman, the quirky coroner; Chin\'s cousin, Kono Kalakaua, a beautiful and fearless native; and Captain Lou Grover, who formerly headed Hawaii\'s SWAT unit. Joining them is Jerry Ortega, a former classmate of Chin\'s and the Island\'s local conspiracy theorist. The state\'s brash FIVE-0 unit, who may spar and jest among themselves, remain determined to eliminate the seedy elements from the 50th state.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/213/532575.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/213/532575.jpg', 'Created By': 'Leonard Freeman', 'Ratings': '7.6', 'Ratings Count': '204', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552ad'), 'name': 'Hellsing', 'Show URL': 'https://www.tvmaze.com/shows/25/hellsing', 'Show Type': 'Animation', 'Language': 'Japanese', 'Genres': ['Anime', 'Horror', 'Supernatural'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2001-10-10', 'Official Site': 'NA', 'Time': 'NA', 'Day': ['Wednesday'], 'Network': 'Fuji TV', 'Country': 'Japan', 'Country Code': 'JP', 'Timezone': 'Asia/Tokyo', 'Summary': "Hellsing is a 13-part anime based on the manga of the same name. The plot is significantly difficult to that of the the manga although the characters are the same. The show mainly focuses on the hellsing institute that houses the anti-hero named Alucard who swore loyalty to the Helsing family many years before. Alucard being the first ever vampire takes on a new apprentice named Sera's.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/178/446544.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/178/446544.jpg', 'Created By': 'NA', 'Ratings': '7.8', 'Ratings Count': '19', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552ae'), 'name': 'Hellsing Ultimate', 'Show URL': 'https://www.tvmaze.com/shows/26/hellsing-ultimate', 'Show Type': 'Animation', 'Language': 'Japanese', 'Genres': ['Drama', 'Action', 'Anime', 'Horror'], 'Status': 'Ended', 'Runtime': 50.0, 'Premiere Date': '2006-02-10', 'Official Site': 'NA', 'Time': '12:00', 'Day': ['Wednesday'], 'Network': 'TBS', 'Country': 'Japan', 'Country Code': 'JP', 'Timezone': 'Asia/Tokyo', 'Summary': "Hellsing Ultimate, unlike the 13-part Hellsing series, follows the manga of the same name very closely. Alucard being the main protagonist and anti-hero/vampire. Hellsing Ultimate is a 10-part series of OVAs whereby Alucard turns Sera's into a vampire. The main focus of the plot being on an enemy neo-nazi group.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/178/446780.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/178/446780.jpg', 'Created By': 'Kohta Hirano', 'Ratings': '7.9', 'Ratings Count': '16', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552af'), 'name': 'Berserk', 'Show URL': 'https://www.tvmaze.com/shows/27/berserk', 'Show Type': 'Animation', 'Language': 'Japanese', 'Genres': ['Anime', 'Fantasy', 'Horror'], 'Status': 'Ended', 'Runtime': 25.0, 'Premiere Date': '1997-10-07', 'Official Site': 'NA', 'Time': 'NA', 'Day': ['Tuesday'], 'Network': 'NTV', 'Country': 'Japan', 'Country Code': 'JP', 'Timezone': 'Asia/Tokyo', 'Summary': 'Berserk is a 25-part anime set in a dark fantasy/horror environment whereby the series focuses on the main character guts; a lone swordman who later meets up with a group of mercenaries called the band of the hawk. The leader of this band holds a strange necklace called a behelit that will only lead to evil.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/249.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/249.jpg', 'Created By': 'NA', 'Ratings': '8.5', 'Ratings Count': '20', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b0'), 'name': 'Californication', 'Show URL': 'https://www.tvmaze.com/shows/28/californication', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Comedy'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2007-08-13', 'Official Site': 'http://www.sho.com/sho/californication/home', 'Time': '21:30', 'Day': ['Sunday'], 'Network': 'Showtime', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Californication is a series based around the writer Hank Moody. He moves to California and suffers a writers block as well as many other family and personal issues. His drinking and generally unhealthy lifestyle interrupts his relationships with his long term lover Karen and his daughter Becca as he struggles with his manager Charlie Runkle.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/38/95017.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/38/95017.jpg', 'Created By': 'Tom Kapinos', 'Ratings': '8', 'Ratings Count': '103', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b1'), 'name': 'Vikings', 'Show URL': 'https://www.tvmaze.com/shows/29/vikings', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Action', 'History'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2013-03-03', 'Official Site': 'https://www.history.ca/shows/vikings/', 'Time': '21:00', 'Day': ['Friday'], 'Network': 'History', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': 'Vikings transports us to the brutal and mysterious world of Ragnar Lothbrok, a Viking warrior and farmer who yearns to explore - and raid - the distant shores across the ocean.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/286/715906.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/286/715906.jpg', 'Created By': 'Michael Hirst', 'Ratings': '8.7', 'Ratings Count': '446', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b2'), 'name': 'American Horror Story', 'Show URL': 'https://www.tvmaze.com/shows/30/american-horror-story', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Horror', 'Thriller'], 'Status': 'Running', 'Runtime': 60.0, 'Premiere Date': '2011-10-05', 'Official Site': 'http://www.fxnetworks.com/shows/american-horror-story', 'Time': '22:00', 'Day': ['Wednesday'], 'Network': 'FX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'American Horror Story is an horror television anthology series. Each season is conceived as a self-contained miniseries, following a disparate set of characters and settings, and a storyline with its own beginning, middle, and end. While some actors appear for more than one year, they play completely different roles in each season.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/282/706314.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/282/706314.jpg', 'Created By': 'Brad FalchukRyan Murphy', 'Ratings': '7.8', 'Ratings Count': '230', 'release_year': 2019.0, 'duration': '9 Seasons', 'cast': "Evan Peters, Sarah Paulson, Jessica Lange, Denis O'Hare, Kathy Bates, Angela Bassett, Lily Rabe, Frances Conroy, Cheyenne Jackson, Emma Roberts, Taissa Farmiga, Wes Bentley, Finn Wittrock, Chloë Sevigny, Zachary Quinto, Jamie Brewer, Naomi Grossman, Dylan McDermott, Gabourey Sidibe, Lady Gaga, Mare Winningham, Joseph Fiennes, Michael Chiklis, Matt Bomer, Lizzie Brocheré, Erika Ervin, Mat Fraser, Rose Siggins, Connie Britton, James Cromwell, Adina Porter, Jyoti Amge, Billie Lourde, Alison Pill, Billy Eichner, Leslie Grossman, Colton Haynes, Cuba Gooding Jr., André Holland, Danny Huston"}
# {'_id': ObjectId('6084e305273769203de552b3'), 'name': "Marvel's Agents of S.H.I.E.L.D.", 'Show URL': 'https://www.tvmaze.com/shows/31/marvels-agents-of-shield', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Adventure', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2013-09-24', 'Official Site': 'http://abc.go.com/shows/marvels-agents-of-shield', 'Time': '22:00', 'Day': ['Wednesday'], 'Network': 'ABC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Phil Coulson heads an elite team of fellow agents with the worldwide law-enforcement organization known as S.H.I.E.L.D. (Strategic Homeland Intervention Enforcement and Logistics Division), as they investigate strange occurrences around the globe. Its members -- each of whom brings a specialty to the group -- work with Coulson to protect those who cannot protect themselves from extraordinary and inconceivable threats.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/253/634071.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/253/634071.jpg', 'Created By': 'Joss WhedonJed WhedonMaurissa Tancharoen', 'Ratings': '8', 'Ratings Count': '490', 'release_year': 2020.0, 'duration': '7 Seasons', 'cast': 'Clark Gregg, Ming-Na Wen, Brett Dalton, Chloe Bennet, Iain De Caestecker, Elizabeth Henstridge, Adrianne Palicki, Luke Mitchell, Henry Simmons'}
# {'_id': ObjectId('6084e305273769203de552b4'), 'name': 'Fargo', 'Show URL': 'https://www.tvmaze.com/shows/32/fargo', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Crime'], 'Status': 'Running', 'Runtime': 60.0, 'Premiere Date': '2014-04-15', 'Official Site': 'http://www.fxnetworks.com/fargo', 'Time': '22:00', 'Day': ['Sunday'], 'Network': 'FX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Fargo is a seasonal anthology crime drama with some dark comical elements, inspired by the film Fargo written by the Coen brothers. Each season follows a new case and new characters, all entrenched in the trademark humor, murder and "Minnesota nice" that has made the film an enduring classic.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/267/669639.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/267/669639.jpg', 'Created By': 'Noah Hawley', 'Ratings': '8.9', 'Ratings Count': '287', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b5'), 'name': 'Hemlock Grove', 'Show URL': 'https://www.tvmaze.com/shows/33/hemlock-grove', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Horror', 'Thriller'], 'Status': 'Ended', 'Runtime': 'NA', 'Premiere Date': '2013-04-19', 'Official Site': 'https://www.netflix.com/title/70242310', 'Time': 'NA', 'Day': [], 'Network': 'NA', 'Country': 'NA', 'Country Code': 'NA', 'Timezone': 'NA', 'Summary': 'Secrets are just a part of daily life in the small Pennsylvania town of Hemlock Grove, where the darkest evils hide in plain sight.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/0/305.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/0/305.jpg', 'Created By': 'Lee ShipmanBrian McGreevy', 'Ratings': '7', 'Ratings Count': '60', 'release_year': 2015.0, 'duration': '3 Seasons', 'cast': 'Famke Janssen, Landon Liboiron, Dougray Scott, Bill Skarsgård, Joel de la Fuente, Kaniehtiio Horn, Madeleine Martin, Michael Andreae, Penelope Mitchell, Freya Tingley, Laurie Fortier, Nicole Boivin, Ted Dykstra, Lili Taylor, Aaron Douglas, Kandyse McClure, Marty Adams, Demore Barnes, Madeline Brewer'}
# {'_id': ObjectId('6084e305273769203de552b6'), 'name': 'Helix', 'Show URL': 'https://www.tvmaze.com/shows/34/helix', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Horror', 'Science-Fiction', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-01-10', 'Official Site': 'NA', 'Time': '22:00', 'Day': ['Friday'], 'Network': 'Syfy', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Helix is a science fiction thriller that focuses on a CDC expedition into the arctic. They go there to investigate the potential outbreak of a disease with no idea what they are getting themselves into. They encounter an almost zombie-like threat that could threaten mankind itself whilst the operator of the facility seems to know more than what he is saying.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/126/316697.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/126/316697.jpg', 'Created By': 'Cameron Porsandeh', 'Ratings': '6.5', 'Ratings Count': '90', 'release_year': 2015.0, 'duration': '1 Season', 'cast': 'Billy Campbell, Hiroyuki Sanada, Kyra Zagorsky, Mark Ghanimé, Meegwun Fairbrother, Jordan Hayes, Neil Napier, Matt Long, Severn Thompson, Jeri Ryan, Catherine Lemieux'}
# {'_id': ObjectId('6084e305273769203de552b7'), 'name': 'The Killing', 'Show URL': 'https://www.tvmaze.com/shows/35/the-killing', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Crime', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2011-04-03', 'Official Site': 'http://www.amc.com/shows/the-killing', 'Time': '21:00', 'Day': ['Friday'], 'Network': 'AMC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'The Killing follows Seattle homicide detectives Stephen Holder and Sarah Linden and their work as detectives investigating murders. Sarah Linden takes cases very seriously and has issues keeping her work and family separate, as she pairs up with recovering addict Stephen Holder to solve dark murders.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/216/540157.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/216/540157.jpg', 'Created By': 'NA', 'Ratings': '8.4', 'Ratings Count': '83', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b8'), 'name': 'Intruders', 'Show URL': 'https://www.tvmaze.com/shows/37/intruders', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Fantasy', 'Thriller'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-08-23', 'Official Site': 'http://www.bbc.co.uk/programmes/b04nf78f', 'Time': '22:00', 'Day': ['Saturday'], 'Network': 'BBC America', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'A contemporary, chilling, paranormal tale set in the moody Pacific Northwest, the series spins a fascinating and complex web of drama. As strange, apparently unrelated events start happening, multiple story-lines - a missing wife, an assassin covering his crimes, a child on the run - begin to intertwine to reveal a conspiracy that will forever change our understanding of human nature.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/126/316698.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/126/316698.jpg', 'Created By': 'Glen Morgan', 'Ratings': '6.9', 'Ratings Count': '15', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de552b9'), 'name': 'Z Nation', 'Show URL': 'https://www.tvmaze.com/shows/38/z-nation', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Horror', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-09-12', 'Official Site': 'http://www.syfy.com/znation', 'Time': '21:00', 'Day': ['Friday'], 'Network': 'Syfy', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Z Nation starts three years after the zombie virus has gutted the country, a team of everyday heroes must transport the only known survivor of the plague from New York to California, where the last functioning viral lab waits for his blood. Although the antibodies he carries are the world's last, best hope for a vaccine, he hides a dark secret that threatens them all. With humankind's survival at stake, the ragtag band embarks on a journey of survival across three thousand miles of rusted-out post-apocalyptic America.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/170/426759.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/170/426759.jpg', 'Created By': 'Karl SchaeferCraig Engler', 'Ratings': '7.3', 'Ratings Count': '139', 'release_year': 2018.0, 'duration': '5 Seasons', 'cast': 'Nat Zang, Russell Hodgkinson, Michael Welch, Anastasia Baranova, Kellita Smith, DJ Qualls, Keith Allan, Pisay Pao'}
# ...
# {'_id': ObjectId('6084e305273769203de55377'), 'name': 'GCB', 'Show URL': 'https://www.tvmaze.com/shows/236/gcb', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Comedy', 'Romance'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2012-03-04', 'Official Site': 'http://abc.go.com/shows/gcb', 'Time': '22:00', 'Day': ['Sunday'], 'Network': 'ABC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'Amanda Vaughn once the ultimate high school "mean girl", is forced to return home in disgrace after her marriage ends in scandal. Amanda is nothing like the girl she was 20 years ago, but as her old classmates reacquaint themselves with the new Amanda, will her home town welcome her with open arms or seek revenge? No one in this town is a saint, but that doesn\'t mean they can\'t have a heart. As Amanda and her teenage kids try to adjust to their new lives, the ladies from her past alternate between sympathy and scheming.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/84/212122.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/84/212122.jpg', 'Created By': 'NA', 'Ratings': '7.3', 'Ratings Count': '9', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55378'), 'name': 'Revolution', 'Show URL': 'https://www.tvmaze.com/shows/237/revolution', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Adventure', 'Science-Fiction'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2012-09-17', 'Official Site': 'NA', 'Time': '20:00', 'Day': ['Wednesday'], 'Network': 'NBC', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'What would you do without it all? In this epic adventure, a family struggles to reunite in an American landscape void of electricity: a world of empty cities, local militias and heroic freedom fighters, where every single piece of technology -- computers, planes, cars, phones, even lights -- has mysteriously blacked out forever.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/55/138043.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/55/138043.jpg', 'Created By': 'Eric Kripke', 'Ratings': '7.5', 'Ratings Count': '102', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55379'), 'name': 'Dallas', 'Show URL': 'https://www.tvmaze.com/shows/238/dallas', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Family'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2012-06-13', 'Official Site': 'NA', 'Time': '21:00', 'Day': ['Monday'], 'Network': 'TNT', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Dallas follows Bobby Ewing, now the senior member of the Ewing family following the death of his older brother J.R. Ewing. Following the death of his revered father, John Ross is out to prove he can be just as powerful an ally or enemy as his infamous father. Bobby's adopted son Christopher is newly single and determined to make a name for himself and his family in the world of natural gas. Elena Ramos is the former girlfriend of both John Ross and Christopher who is now blinded by thoughts of justice for previous wrongs. Pamela Rebecca Barnes is John Ross' wife and the daughter of Cliff Barnes, a longtime rival of the Ewings. She is determined to have a happy ending with her husband and make a home on Southfork Ranch. Also featured is Bobby's wife Ann and Harris Ryland, her scheming ex-husband. Emma Ryland is Ann and Harris' daughter, who has been taught by her father and grandmother.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/3848.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/3848.jpg', 'Created By': 'David Jacobs', 'Ratings': '6.3', 'Ratings Count': '8', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5537a'), 'name': 'Anger Management', 'Show URL': 'https://www.tvmaze.com/shows/239/anger-management', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Comedy'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2012-06-28', 'Official Site': 'http://www.fxnetworks.com/angermanagement', 'Time': '22:00', 'Day': ['Monday'], 'Network': 'FX', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'In Anger Management, Charlie is a non-traditional therapist specializing in anger management. He has a successful private practice, holding sessions with his group of primary patients each week, as well as performing pro-bono counseling for an inmate group at a state prison.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/3885.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/3885.jpg', 'Created By': 'Bruce Helford', 'Ratings': '6.7', 'Ratings Count': '30', 'release_year': 2003.0, 'duration': '105 min', 'cast': 'Adam Sandler, Jack Nicholson, Marisa Tomei, Luis Guzmán, Allen Covert, Lynne Thigpen, Kurt Fuller, Jonathan Loughran, Krista Allen, January Jones, Woody Harrelson, John Turturro, Kevin Nealon'}
# {'_id': ObjectId('6084e305273769203de5537b'), 'name': 'Cops', 'Show URL': 'https://www.tvmaze.com/shows/240/cops', 'Show Type': 'Reality', 'Language': 'English', 'Genres': ['Action', 'Crime'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '1989-03-11', 'Official Site': 'http://www.cops.com', 'Time': '22:30', 'Day': ['Monday'], 'Network': 'Paramount Network', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "COPS follows police officers, constables, and sheriff's deputies during patrols and various police activities by embedding camera crews with their units. The show's formula adheres to a classic cinéma vérité ethos. With no narration or scripted dialog, it depends entirely on the commentary of the officers and on the actions of the people with whom they come into contact.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4185.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4185.jpg', 'Created By': 'NA', 'Ratings': '8', 'Ratings Count': '21', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5537c'), 'name': 'Benched', 'Show URL': 'https://www.tvmaze.com/shows/241/benched', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Comedy', 'Legal'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2014-10-28', 'Official Site': 'http://www.usanetwork.com/benched', 'Time': '22:30', 'Day': ['Tuesday'], 'Network': 'USA Network', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Benched is a single-camera comedy about a high-powered corporate lawyer's fall from grace into the rough-and-tumble world of the public defenders. From ABC Signature Studio, it stars Coupe as Nina Whitley, a distinguished corporate lawyer who has given up everything in her climb to the top. However, when she's hit with her ex-fiancé's engagement announcement and learns that she hasn't made partner at her high power firm, Nina snaps -- breaking vases and burning bridges.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4351.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4351.jpg', 'Created By': 'NA', 'Ratings': '6.7', 'Ratings Count': '11', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5537d'), 'name': 'The Great Fire', 'Show URL': 'https://www.tvmaze.com/shows/242/the-great-fire', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-10-16', 'Official Site': 'NA', 'Time': '21:00', 'Day': ['Thursday'], 'Network': 'ITV', 'Country': 'United Kingdom', 'Country Code': 'GB', 'Timezone': 'Europe/London', 'Summary': 'As the great fire tears London apart, this brand new epic drama details the heart-wrenching stories of a city and its people in crisis.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4358.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4358.jpg', 'Created By': 'NA', 'Ratings': '7', 'Ratings Count': '4', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5537e'), 'name': 'Conan', 'Show URL': 'https://www.tvmaze.com/shows/243/conan', 'Show Type': 'Talk Show', 'Language': 'English', 'Genres': ['Comedy'], 'Status': 'Running', 'Runtime': 30.0, 'Premiere Date': '2010-11-08', 'Official Site': 'https://teamcoco.com', 'Time': '23:00', 'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday'], 'Network': 'TBS', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "The biggest celebrities, the hottest musical guests, the craziest sketches... and Andy Richter, to boot? Yes, some would say Conan O'Brien's talk show on TBS has everything a late night viewer could want.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4583.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4583.jpg', 'Created By': "Andy RichterConan O'Brien", 'Ratings': '7.5', 'Ratings Count': '30', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de5537f'), 'name': 'Strange Empire', 'Show URL': 'https://www.tvmaze.com/shows/244/strange-empire', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Drama', 'Western'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-10-06', 'Official Site': 'http://www.cbc.ca/strangeempire/', 'Time': '21:00', 'Day': ['Monday'], 'Network': 'CBC', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': "Strange Empire is a Western whose heroes are women. With most of their men gone, and those who remain battling for control, the women struggle to survive, to find their independence, and to build a life in which to thrive and raise families. As the stories of Janestown's citizens unfold we see the clash between a power-hungry father and son and the deep prejudices among races, but also the start of something akin to community in this Wild West. Western stories take civilization as a goal; they begin in blood, and end in the morality of Main Street.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4585.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4585.jpg', 'Created By': 'Laurie Finstad Knizhnik', 'Ratings': '7.2', 'Ratings Count': '11', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55380'), 'name': 'Town of the Living Dead', 'Show URL': 'https://www.tvmaze.com/shows/245/town-of-the-living-dead', 'Show Type': 'Reality', 'Language': 'English', 'Genres': [], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2014-10-07', 'Official Site': 'NA', 'Time': '22:00', 'Day': ['Tuesday'], 'Network': 'Syfy', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'In Town of the Living Dead, the colorful folks of Jasper, Alabama are determined, once and for all, to complete their zombie movie, Thr33 Days Dead... now six long years in the making. Based on a town urban legend, their film centers on a group of friends trying to survive a zombie apocalypse in rural Alabama. The series will follow the intrepid and motley crew of amateur filmmakers as they struggle against every obstacle imaginable to get to a final cut of their film... which could someday become a Syfy movie.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4590.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4590.jpg', 'Created By': 'NA', 'Ratings': 'NA', 'Ratings Count': 'NA', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55381'), 'name': 'Long Shadow', 'Show URL': 'https://www.tvmaze.com/shows/246/long-shadow', 'Show Type': 'Documentary', 'Language': 'English', 'Genres': ['War', 'History'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2014-09-24', 'Official Site': 'http://www.bbc.co.uk/programmes/b04jqxtl', 'Time': '20:00', 'Day': ['Wednesday'], 'Network': 'BBC Two', 'Country': 'United Kingdom', 'Country Code': 'GB', 'Timezone': 'Europe/London', 'Summary': 'David Reynolds traces the legacy of the Great War across 100 years and 10 different countries, examining how the war haunted a generation and shaped the peace that followed.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4591.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4591.jpg', 'Created By': 'NA', 'Ratings': 'NA', 'Ratings Count': 'NA', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55382'), 'name': 'The Colbert Report', 'Show URL': 'https://www.tvmaze.com/shows/247/the-colbert-report', 'Show Type': 'Talk Show', 'Language': 'English', 'Genres': ['Comedy'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '2005-10-17', 'Official Site': 'NA', 'Time': '23:30', 'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday'], 'Network': 'Comedy Central', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': "Feel the news along with Stephen Colbert, America's ballsiest pundit.", 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4592.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4592.jpg', 'Created By': 'Stephen Colbert', 'Ratings': '7.5', 'Ratings Count': '13', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55383'), 'name': 'Transporter: The Series', 'Show URL': 'https://www.tvmaze.com/shows/248/transporter-the-series', 'Show Type': 'Scripted', 'Language': 'English', 'Genres': ['Action', 'Adventure', 'Crime'], 'Status': 'Ended', 'Runtime': 60.0, 'Premiere Date': '2013-01-04', 'Official Site': 'NA', 'Time': '21:00', 'Day': ['Sunday'], 'Network': 'The Movie Network', 'Country': 'Canada', 'Country Code': 'CA', 'Timezone': 'America/Halifax', 'Summary': 'Frank Martin returns as the Transporter with one very simple task - to deliver the package against all the odds. However, something that sounds so simple, is rarely so.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4593.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4593.jpg', 'Created By': 'NA', 'Ratings': '7.2', 'Ratings Count': '38', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
# {'_id': ObjectId('6084e305273769203de55384'), 'name': 'The Daily Show with Jon Stewart', 'Show URL': 'https://www.tvmaze.com/shows/249/the-daily-show-with-jon-stewart', 'Show Type': 'Talk Show', 'Language': 'English', 'Genres': ['Comedy'], 'Status': 'Ended', 'Runtime': 30.0, 'Premiere Date': '1999-01-11', 'Official Site': 'NA', 'Time': '23:00', 'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday'], 'Network': 'Comedy Central', 'Country': 'United States', 'Country Code': 'US', 'Timezone': 'America/New_York', 'Summary': 'One anchor, several correspondents, zero credibility.', 'Full Img': 'http://static.tvmaze.com/uploads/images/original_untouched/1/4598.jpg', 'Med img': '//static.tvmaze.com/uploads/images/medium_portrait/1/4598.jpg', 'Created By': 'Madeleine SmithbergLizz Winstead', 'Ratings': '8.2', 'Ratings Count': '29', 'release_year': 'NA', 'duration': 'NA', 'cast': 'NA'}
